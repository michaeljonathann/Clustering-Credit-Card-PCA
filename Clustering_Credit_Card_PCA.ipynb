# %% [markdown]
# <a href="https://colab.research.google.com/github/michaeljonathann/Clustering-Credit-Card-PCA/blob/main/Clustering_Credit_Card_PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Libraries & Data Load**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import pairwise_distances

# %%
from google.colab import files
gambar_asli = files.upload()
# Out:
#      <input type="file" id="files-10e0c827-d89d-4d1a-9a23-3d28164fe46f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10e0c827-d89d-4d1a-9a23-3d28164fe46f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_cc = pd.read_csv('CC GENERAL.csv')
df_cc
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %% [markdown]
# # **Data Preprocessing**

# %%
df_cc.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE'],
#       dtype='object')

# %%
df_cc.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df_cc.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
# handled these missing values by replacing them by means
df_cc['CREDIT_LIMIT'].fillna(df_cc['CREDIT_LIMIT'].mean(), inplace=True)
df_cc['MINIMUM_PAYMENTS'].fillna(df_cc['MINIMUM_PAYMENTS'].mean(), inplace=True)

# %%
df_cc.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df_cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
# CUST_ID has a data types object, so I dropped it
df_cc.drop('CUST_ID', axis=1, inplace=True)
df_cc.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %% [markdown]
# **Data Normalization**

# %%
df_cc.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
scaler = StandardScaler()
scaled_df = scaler.fit_transform(df_cc)

# %%
# Normalizing the Data
normalized_df = normalize(scaled_df)

# Converting the numpy array into a pandas DataFrame
normalized_df = pd.DataFrame(normalized_df)

# %% [markdown]
# **Dimension Reduction using PCA**

# %%
pca = PCA(n_components = 2)
X_principal = pca.fit_transform(normalized_df)
X_principal = pd.DataFrame(X_principal)
X_principal.columns = ['P1', 'P2']
X_principal.head(2)
# Out:
#          P1        P2
# 0 -0.489826 -0.679678
# 1 -0.518791  0.545012

# %% [markdown]
# # **Clustering**

# %% [markdown]
# **Choosing the K**

# %%
sse = {}
for k in range(1, 15):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(X_principal)
    sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# It's hard to find the elbow point of the curve, so we use silhouette score.

# %%
silhouette_scores = []

for n_cluster in range(2, 8):
    silhouette_scores.append(
        silhouette_score(X_principal, KMeans(n_clusters = n_cluster).fit_predict(X_principal)))

# Plotting a bar graph to compare the results
k = [2, 3, 4, 5, 6, 7]
plt.bar(k, silhouette_scores)
plt.xlabel('Number of clusters', fontsize = 10)
plt.ylabel('Silhouette Score', fontsize = 10)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
kmean= KMeans(3)
kmean.fit(scaled_df)
labels=kmean.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
def davies_bouldin_index(data, labels):
    num_clusters = len(np.unique(labels))
    cluster_centers = []
    for i in range(num_clusters):
        cluster_centers.append(np.mean(data[labels == i], axis=0))

    # Calculate the pairwise distances between cluster centers
    center_distances = pairwise_distances(cluster_centers)

    # Calculate the average distance within each cluster
    avg_cluster_distances = []
    for i in range(num_clusters):
        avg_cluster_distances.append(np.mean(pairwise_distances(data[labels == i], cluster_centers[i].reshape(1, -1))))

    # Calculate the Davies-Bouldin Index
    dbi_scores = []
    for i in range(num_clusters):
        max_dbi = -np.inf
        for j in range(num_clusters):
            if j != i:
                dbi = (avg_cluster_distances[i] + avg_cluster_distances[j]) / center_distances[i, j]
                if dbi > max_dbi:
                    max_dbi = dbi
        dbi_scores.append(max_dbi)

    return np.mean(dbi_scores)

# %%
# Calculate the Davies-Bouldin Index
dbi = davies_bouldin_index(scaled_df, labels)
print("Davies-Bouldin Index:", dbi)
# Out:
# Davies-Bouldin Index: 1.5972709940037866

# %%
clusters=pd.concat([df_cc, pd.DataFrame({'cluster':labels})], axis=1)
clusters.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %% [markdown]
# **Interpretation of Cluster**

# %%
for c in clusters:
    grid= sns.FacetGrid(clusters, col='cluster')
    grid.map(plt.hist, c)

# %%
clusters['cluster'].value_counts()
# Out:
# 1    6119
# 0    1596
# 2    1235
# Name: cluster, dtype: int64

# %%
clusters.groupby('cluster').mean()
# Out:
#              BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# cluster
# 0        3989.326804           0.957980   384.528277        248.718133
# 1         799.702576           0.835188   505.532394        253.120131
# 2        2220.003291           0.981477  4268.520980       2717.828543
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# cluster
# 0                    135.887632   3869.856855             0.232290
# 1                    252.733061    329.866776             0.465072
# 2                   1551.178267    458.421147             0.949093
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# cluster
# 0                          0.110942                          0.144242
# 1                          0.132333                          0.345145
# 2                          0.668166                          0.744584
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# cluster
# ...

# %% [markdown]
# # **Visualization**

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(normalized_df)
principalDf = pd.DataFrame(data = principalComponents, columns=['principal component 1', 'principal component 2'])
principalDf.head(2)
# Out:
#    principal component 1  principal component 2
# 0              -0.489826              -0.679678
# 1              -0.518791               0.545009

# %%
finalDf = pd.concat([principalDf, pd.DataFrame({'cluster':labels})], axis = 1)
finalDf.head()
# Out:
#    principal component 1  principal component 2  cluster
# 0              -0.489826              -0.679678        1
# 1              -0.518791               0.545009        0
# 2               0.330885               0.268978        1
# 3              -0.482374              -0.092111        1
# 4              -0.563289              -0.481914        1

# %%
plt.figure(figsize=(15,10))
ax = sns.scatterplot(x="principal component 1", y="principal component 2", hue="cluster", data=finalDf,palette=['red','blue','green'])
plt.show()

# %% [markdown]
# # **2 Cluster**

# %%
kmean= KMeans(2)
kmean.fit(scaled_df)
labels=kmean.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
def davies_bouldin_index(data, labels):
    num_clusters = len(np.unique(labels))
    cluster_centers = []
    for i in range(num_clusters):
        cluster_centers.append(np.mean(data[labels == i], axis=0))

    # Calculate the pairwise distances between cluster centers
    center_distances = pairwise_distances(cluster_centers)

    # Calculate the average distance within each cluster
    avg_cluster_distances = []
    for i in range(num_clusters):
        avg_cluster_distances.append(np.mean(pairwise_distances(data[labels == i], cluster_centers[i].reshape(1, -1))))

    # Calculate the Davies-Bouldin Index
    dbi_scores = []
    for i in range(num_clusters):
        max_dbi = -np.inf
        for j in range(num_clusters):
            if j != i:
                dbi = (avg_cluster_distances[i] + avg_cluster_distances[j]) / center_distances[i, j]
                if dbi > max_dbi:
                    max_dbi = dbi
        dbi_scores.append(max_dbi)

    return np.mean(dbi_scores)

# %%
# Calculate the Davies-Bouldin Index
dbi = davies_bouldin_index(scaled_df, labels)
print("Davies-Bouldin Index:", dbi)
# Out:
# Davies-Bouldin Index: 1.912244367543547

# %%
clusters=pd.concat([df_cc, pd.DataFrame({'cluster':labels})], axis=1)
clusters.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
for c in clusters:
    grid= sns.FacetGrid(clusters, col='cluster')
    grid.map(plt.hist, c)

# %%
clusters['cluster'].value_counts()
# Out:
# 0    5222
# 1    3728
# Name: cluster, dtype: int64

# %%
clusters.groupby('cluster').mean()
# Out:
#              BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# cluster
# 0        1698.313812           0.828754   275.961588        201.348594
# 1        1376.999727           0.945231  2021.891591       1140.255394
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# cluster
# 0                     74.892989   1366.543948             0.194687
# 1                    881.964654    435.837972             0.904502
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# cluster
# 0                          0.088468                          0.103808
# 1                          0.362129                          0.729515
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# cluster
# 0                       0.18989          4.560513       3.346419
# 1                       0.05846          1.411481      30.627146
#
#          CREDIT_LIMIT     PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  \
# cluster
# ...

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(normalized_df)
principalDf = pd.DataFrame(data = principalComponents, columns=['principal component 1', 'principal component 2'])
principalDf.head(2)
# Out:
#    principal component 1  principal component 2
# 0              -0.489826              -0.679678
# 1              -0.518791               0.545012

# %%
finalDf = pd.concat([principalDf, pd.DataFrame({'cluster':labels})], axis = 1)
finalDf.head()
# Out:
#    principal component 1  principal component 2  cluster
# 0              -0.489826              -0.679678        0
# 1              -0.518791               0.545012        0
# 2               0.330885               0.268974        1
# 3              -0.482374              -0.092112        0
# 4              -0.563289              -0.481913        0

# %%
plt.figure(figsize=(15,10))
ax = sns.scatterplot(x="principal component 1", y="principal component 2", hue="cluster", data=finalDf,palette=['red','blue'])
plt.show()

# %% [markdown]
# # **4 Cluster**

# %%
kmean= KMeans(4)
kmean.fit(scaled_df)
labels=kmean.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
def davies_bouldin_index(data, labels):
    num_clusters = len(np.unique(labels))
    cluster_centers = []
    for i in range(num_clusters):
        cluster_centers.append(np.mean(data[labels == i], axis=0))

    # Calculate the pairwise distances between cluster centers
    center_distances = pairwise_distances(cluster_centers)

    # Calculate the average distance within each cluster
    avg_cluster_distances = []
    for i in range(num_clusters):
        avg_cluster_distances.append(np.mean(pairwise_distances(data[labels == i], cluster_centers[i].reshape(1, -1))))

    # Calculate the Davies-Bouldin Index
    dbi_scores = []
    for i in range(num_clusters):
        max_dbi = -np.inf
        for j in range(num_clusters):
            if j != i:
                dbi = (avg_cluster_distances[i] + avg_cluster_distances[j]) / center_distances[i, j]
                if dbi > max_dbi:
                    max_dbi = dbi
        dbi_scores.append(max_dbi)

    return np.mean(dbi_scores)

# %%
# Calculate the Davies-Bouldin Index
dbi = davies_bouldin_index(scaled_df, labels)
print("Davies-Bouldin Index:", dbi)
# Out:
# Davies-Bouldin Index: 1.5751510009640766

# %%
clusters=pd.concat([df_cc, pd.DataFrame({'cluster':labels})], axis=1)
clusters.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
for c in clusters:
    grid= sns.FacetGrid(clusters, col='cluster')
    grid.map(plt.hist, c)

# %%
clusters['cluster'].value_counts()
# Out:
# 0    3976
# 3    3367
# 2    1198
# 1     409
# Name: cluster, dtype: int64

# %%
clusters.groupby('cluster').mean()
# Out:
#              BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# cluster
# 0        1011.751528           0.789871   269.973466        209.853863
# 1        3551.153761           0.986879  7681.620098       5095.878826
# 2        4602.462714           0.968415   501.896219        320.373681
# 3         894.907458           0.934734  1236.178934        593.974874
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# cluster
# 0                     60.386625    595.759339             0.170146
# 1                   2587.208264    653.638891             0.946418
# 2                    181.607404   4520.724309             0.287731
# 3                    642.478274    210.570626             0.885165
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# cluster
# 0                          0.086281                          0.080578
# 1                          0.739031                          0.788060
# ...

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(normalized_df)
principalDf = pd.DataFrame(data = principalComponents, columns=['principal component 1', 'principal component 2'])
principalDf.head(2)
# Out:
#    principal component 1  principal component 2
# 0              -0.489825              -0.679678
# 1              -0.518791               0.545011

# %%
finalDf = pd.concat([principalDf, pd.DataFrame({'cluster':labels})], axis = 1)
finalDf.head()
# Out:
#    principal component 1  principal component 2  cluster
# 0              -0.489825              -0.679678        0
# 1              -0.518791               0.545011        2
# 2               0.330885               0.268981        3
# 3              -0.482373              -0.092117        0
# 4              -0.563289              -0.481913        0

# %%
plt.figure(figsize=(15,10))
ax = sns.scatterplot(x="principal component 1", y="principal component 2", hue="cluster", data=finalDf,palette=['red','blue','green','yellow'])
plt.show()
